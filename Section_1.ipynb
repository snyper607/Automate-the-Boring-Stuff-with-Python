# %% [markdown]
# ### This is my first coding experience with Python
# -  This is my first coding experience with Python
# -  This is my first coding experience with Python
# -  This is my first coding experience with Python

# %%
a=1

# %%
b=2

# %%
c=a+b

# %%
c
# Out:
# 3

# %%
a=1

# %%
a
# Out:
# 1

# %%
...
